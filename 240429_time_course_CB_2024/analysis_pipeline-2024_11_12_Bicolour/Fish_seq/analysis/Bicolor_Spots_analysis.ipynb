# %%
FIGSIZE = (15,15)
BINS = 100

EXPECTED_TREATMENT_NUMBER = 6
SIGNIFICANCE = 0.01

SINGLE_MOLECULES_KEYS = []
OTHER_KEYS = ["cell_line","treatment"]

PATH_IN= "/media/floricslimani/SSD 4To/SSD_floricslimani/Fish_seq/Manon/time_course_CB/pipeline_output/240429_time_course_CB_20240805_16-13-15/result_tables/"

Z_SCORE = 2.575829 # 99% confidence interval

# %%
import pandas as pd

Acquisition = pd.read_feather(PATH_IN + '/Acquisition.feather')
Cell = pd.read_feather(PATH_IN + '/Cell.feather')
Spots = pd.read_feather(PATH_IN + '/Spots.feather')

print(Spots)
# Out:
#         cell_id  spots_id      coordinates spot_type population  intensity  \
# 0             8         0     [0, 75, 546]      rna1       free     7207.0
# 1          1955         0     [0, 90, 993]      rna1       free     8146.0
# 2          3525         0   [0, 132, 1181]      rna1       free     6220.0
# 3          1890         0    [0, 22, 1423]      rna1       free     7474.0
# 4          1820         0     [0, 68, 128]      rna1       free     8198.0
# ...         ...       ...              ...       ...        ...        ...
# 537386     2317     20007  [24, 1599, 111]      rna1  clustered     9719.0
# 537387     2317     20008  [24, 1629, 117]      rna1  clustered    12904.0
# 537388     2317     20009  [24, 1629, 116]      rna1  clustered    12577.0
# 537389     2317     20010  [24, 1627, 118]      rna1  clustered    11256.0
# 537390     2317     20011  [24, 1629, 119]      rna1  clustered    10906.0
#
#         acquisition_id
# 0                  0.0
# 1                 20.0
# 2                 51.0
# 3                 19.0
# 4                 18.0
# ...                ...
# 537386            37.0
# 537387            37.0
# 537388            37.0
# 537389            37.0
# 537390            37.0
#
# [537391 rows x 7 columns]
